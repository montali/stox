# %% [markdown]
# # What we'll want to do
# - Download the stock price history, calculate percentage of growth for each day
# - Fetch all the data
#     - Download from Twitter, Reddit, Reuters and Yahoo Finance
#     - Perform sentiment analysis on the single
#
#
# ## Possible features
# - Qty of positive negative neutral tweets/reddit comments/articles
# - Starting price
# - Last day percentage
#
#
# TODO
# - Adapt the text RNN to these texts
# - y will be the percentage of growth
# - repeat this for a set of firms
# - get the highest percentages of growth
#
# To construct the dataset:
# - Define a function that gets the percentage (starting price-closing price / starting) given a stock symbol and a day
# - Define a function that calls the latter and iterates over N days
# - Define 3 functions that get tweets/articles/reddit comments given a stock symbol and a day (this will use a JSON containing the search terms)
# - Define a function that calls the previous ones, creates a dataset of texts->stock changing
#
# ## API Key for AlphaVantage
# `XWJ7JPW4QLVIHMTU`

# %%
import pandas as pd

# %%
API_KEY = "XWJ7JPW4QLVIHMTU"
API_FUNCTION = "TIME_SERIES_DAILY_ADJUSTED"
OUTPUT_SIZE = "full"
N_DAYS = 1000

# %%
def get_stock_dataframe(symbol):
    endpoint = "https://www.alphavantage.co/query?function={}&symbol={}&outputsize={}&apikey={}&datatype=csv".format(API_FUNCTION,symbol, OUTPUT_SIZE, API_KEY)
    dataframe = pd.read_csv(endpoint)
    dataframe["change"] = (dataframe['close']-dataframe['open'])/dataframe['open']
    dataframe = dataframe.head(3000) # No ancient shit please
    return dataframe

# %%
# !pip3 install --force-reinstall git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Collecting twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /private/var/folders/yl/3bwgxtvd3d55k4h9wn4c996w0000gn/T/pip-install-awuqklpt/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
# Collecting aiohttp
#   Using cached aiohttp-3.7.2-cp36-cp36m-macosx_10_14_x86_64.whl (649 kB)
# Collecting aiodns
#   Using cached aiodns-2.0.0-py2.py3-none-any.whl (4.8 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting cchardet
#   Using cached cchardet-2.1.7-cp36-cp36m-macosx_10_9_x86_64.whl (124 kB)
# Collecting dataclasses
#   Using cached dataclasses-0.7-py3-none-any.whl (18 kB)
# Collecting elasticsearch
#   Using cached elasticsearch-7.9.1-py2.py3-none-any.whl (219 kB)
# Collecting pysocks
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pandas
#   Using cached pandas-1.1.4-cp36-cp36m-macosx_10_9_x86_64.whl (10.2 MB)
# Collecting aiohttp_socks
#   Using cached aiohttp_socks-0.5.5-py3-none-any.whl (9.1 kB)
# Collecting schedule
#   Using cached schedule-0.6.0-py2.py3-none-any.whl (8.7 kB)
# Collecting geopy
#   Using cached geopy-2.0.0-py3-none-any.whl (111 kB)
# Processing /Users/simone/Library/Caches/pip/wheels/12/8a/a1/0ab79c1c2c58aa7647d0dea17f2af2358b65e1eecac8094b5e/fake_useragent-0.1.11-py3-none-any.whl
# Processing /Users/simone/Library/Caches/pip/wheels/3d/6a/dd/6c457dbd4bd762f2623b1d5cff69acf8420262feee858bf26e/googletransx-2.4.2-py3-none-any.whl
# Processing /Users/simone/Library/Caches/pip/wheels/6a/f5/9c/f8331a854f7a8739cf0e74c13854e4dd7b1af11b04fe1dde13/idna_ssl-1.1.0-py3-none-any.whl
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-5.0.0-cp36-cp36m-macosx_10_14_x86_64.whl (48 kB)
# Collecting async-timeout<4.0,>=3.0
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting chardet<4.0,>=2.0
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting typing-extensions>=3.6.5
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.6.2-cp36-cp36m-macosx_10_14_x86_64.whl (128 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# Collecting pycares>=3.0.0
#   Using cached pycares-3.1.1-cp36-cp36m-macosx_10_6_intel.whl (121 kB)
# Processing /Users/simone/Library/Caches/pip/wheels/5f/63/c2/b85489bbea28cb5d36cfe197244f898428004fa3caa7a23116/typing-3.7.4.3-py3-none-any.whl
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Collecting urllib3>=1.21.1
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Collecting certifi
#   Downloading certifi-2020.11.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 467 kB/s eta 0:00:01
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting numpy>=1.15.4
#   Using cached numpy-1.19.4-cp36-cp36m-macosx_10_9_x86_64.whl (15.3 MB)
# Collecting pytz>=2017.2
#   Using cached pytz-2020.4-py2.py3-none-any.whl (509 kB)
# Collecting python-socks[asyncio]>=1.0.1
#   Using cached python_socks-1.1.0-py3-none-any.whl (32 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.50-py3-none-any.whl (38 kB)
# Collecting requests
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting idna>=2.0
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting cffi>=1.5.0
#   Using cached cffi-1.14.3-2-cp36-cp36m-macosx_10_9_x86_64.whl (176 kB)
# Collecting six>=1.5
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting pycparser
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: twint
#   Building wheel for twint (setup.py) ... done
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=38673 sha256=e93836b1aebe16bf317cb219959d488d80ba02e2d47b7c292f81e59a40fbe45e
#   Stored in directory: /private/var/folders/yl/3bwgxtvd3d55k4h9wn4c996w0000gn/T/pip-ephem-wheel-cache-l6w2lxs7/wheels/c9/d4/7d/fb0732852f335c92c52450e5c86b6ba5fb09fa226f3584db34
# Successfully built twint
# Installing collected packages: idna, idna-ssl, multidict, async-timeout, chardet, typing-extensions, yarl, attrs, aiohttp, pycparser, cffi, pycares, typing, aiodns, soupsieve, beautifulsoup4, cchardet, dataclasses, urllib3, certifi, elasticsearch, pysocks, six, python-dateutil, numpy, pytz, pandas, python-socks, aiohttp-socks, schedule, geographiclib, geopy, fake-useragent, requests, googletransx, twint
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: idna-ssl
#     Found existing installation: idna-ssl 1.1.0
#     Uninstalling idna-ssl-1.1.0:
#       Successfully uninstalled idna-ssl-1.1.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 5.0.0
#     Uninstalling multidict-5.0.0:
#       Successfully uninstalled multidict-5.0.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 3.0.1
#     Uninstalling async-timeout-3.0.1:
#       Successfully uninstalled async-timeout-3.0.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.6.2
#     Uninstalling yarl-1.6.2:
#       Successfully uninstalled yarl-1.6.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.7.2
#     Uninstalling aiohttp-3.7.2:
#       Successfully uninstalled aiohttp-3.7.2
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.20
#     Uninstalling pycparser-2.20:
#       Successfully uninstalled pycparser-2.20
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.14.3
#     Uninstalling cffi-1.14.3:
#       Successfully uninstalled cffi-1.14.3
#   Attempting uninstall: pycares
#     Found existing installation: pycares 3.1.1
#     Uninstalling pycares-3.1.1:
#       Successfully uninstalled pycares-3.1.1
#   Attempting uninstall: typing
#     Found existing installation: typing 3.7.4.3
#     Uninstalling typing-3.7.4.3:
#       Successfully uninstalled typing-3.7.4.3
#   Attempting uninstall: aiodns
#     Found existing installation: aiodns 2.0.0
#     Uninstalling aiodns-2.0.0:
#       Successfully uninstalled aiodns-2.0.0
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.0.1
#     Uninstalling soupsieve-2.0.1:
#       Successfully uninstalled soupsieve-2.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.3
#     Uninstalling beautifulsoup4-4.9.3:
#       Successfully uninstalled beautifulsoup4-4.9.3
#   Attempting uninstall: cchardet
#     Found existing installation: cchardet 2.1.7
#     Uninstalling cchardet-2.1.7:
#       Successfully uninstalled cchardet-2.1.7
#   Attempting uninstall: dataclasses
#     Found existing installation: dataclasses 0.7
#     Uninstalling dataclasses-0.7:
#       Successfully uninstalled dataclasses-0.7
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.6.20
#     Uninstalling certifi-2020.6.20:
#       Successfully uninstalled certifi-2020.6.20
#   Attempting uninstall: elasticsearch
#     Found existing installation: elasticsearch 7.9.1
#     Uninstalling elasticsearch-7.9.1:
#       Successfully uninstalled elasticsearch-7.9.1
#   Attempting uninstall: pysocks
#     Found existing installation: PySocks 1.7.1
#     Uninstalling PySocks-1.7.1:
#       Successfully uninstalled PySocks-1.7.1
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.4
#     Uninstalling numpy-1.19.4:
#       Successfully uninstalled numpy-1.19.4
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2020.4
#     Uninstalling pytz-2020.4:
#       Successfully uninstalled pytz-2020.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.4
#     Uninstalling pandas-1.1.4:
#       Successfully uninstalled pandas-1.1.4
#   Attempting uninstall: python-socks
#     Found existing installation: python-socks 1.1.0
#     Uninstalling python-socks-1.1.0:
#       Successfully uninstalled python-socks-1.1.0
#   Attempting uninstall: aiohttp-socks
#     Found existing installation: aiohttp-socks 0.5.5
#     Uninstalling aiohttp-socks-0.5.5:
#       Successfully uninstalled aiohttp-socks-0.5.5
#   Attempting uninstall: schedule
#     Found existing installation: schedule 0.6.0
#     Uninstalling schedule-0.6.0:
#       Successfully uninstalled schedule-0.6.0
#   Attempting uninstall: geographiclib
#     Found existing installation: geographiclib 1.50
#     Uninstalling geographiclib-1.50:
#       Successfully uninstalled geographiclib-1.50
#   Attempting uninstall: geopy
#     Found existing installation: geopy 2.0.0
#     Uninstalling geopy-2.0.0:
#       Successfully uninstalled geopy-2.0.0
#   Attempting uninstall: fake-useragent
#     Found existing installation: fake-useragent 0.1.11
#     Uninstalling fake-useragent-0.1.11:
#       Successfully uninstalled fake-useragent-0.1.11
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
#   Attempting uninstall: googletransx
#     Found existing installation: googletransx 2.4.2
#     Uninstalling googletransx-2.4.2:
#       Successfully uninstalled googletransx-2.4.2
#   Attempting uninstall: twint
#     Found existing installation: twint 2.1.21
#     Uninstalling twint-2.1.21:
#       Successfully uninstalled twint-2.1.21
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# streamlit 0.52.1 requires python-dateutil<=2.8.0, but you'll have python-dateutil 2.8.1 which is incompatible.
# streamlit 0.52.1 requires tornado<6.0,>=5.0, but you'll have tornado 6.0.4 which is incompatible.
# Successfully installed aiodns-2.0.0 aiohttp-3.7.2 aiohttp-socks-0.5.5 async-timeout-3.0.1 attrs-20.3.0 beautifulsoup4-4.9.3 cchardet-2.1.7 certifi-2020.11.8 cffi-1.14.3 chardet-3.0.4 dataclasses-0.7 elasticsearch-7.9.1 fake-useragent-0.1.11 geographiclib-1.50 geopy-2.0.0 googletransx-2.4.2 idna-2.10 idna-ssl-1.1.0 multidict-5.0.0 numpy-1.19.4 pandas-1.1.4 pycares-3.1.1 pycparser-2.20 pysocks-1.7.1 python-dateutil-2.8.1 python-socks-1.1.0 pytz-2020.4 requests-2.24.0 schedule-0.6.0 six-1.15.0 soupsieve-2.0.1 twint-2.1.21 typing-3.7.4.3 typing-extensions-3.7.4.3 urllib3-1.25.11 yarl-1.6.2

# %%
import emoji

def clean_text_from_emoji(text):
    allchars = [str for str in text]
    emoji_list = [c for c in allchars if c in emoji.UNICODE_EMOJI]
    clean_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])

    return clean_text

# %%
import re

def clean_text(text):
    text = re.sub(r'https?:\/\/\S*[\s]', '', text, flags=re.MULTILINE)
    text = clean_text_from_emoji(text)
    return text

# %%
import os
import re
import subprocess

def get_tweets(keywords, date):
    # Getting the day for the Since parameter in tweets download
    date_split = date.split('-')
    date_before = int(date_split[2])-1
    date_before_string = date_split[0]+'-'+date_split[1]+'-'+str(date_before)
    result = []
    for keyword in keywords:
        print("Fetching keyword {}".format(keyword))
        command = "twint -s '{}' -o {}-{}.csv --csv --since '{}' --until '{}' --limit 1 --lang en".format(keyword, keyword, date, date_before_string, date)
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
        process.wait()
        tweet_data = pd.read_csv("{}-{}.csv".format(keyword, date), delimiter="\t")
        result.append(tweet_data["tweet"])
    full_df = pd.concat(result, ignore_index=True)
    full_df.drop_duplicates()
    out = ' '.join(full_df)
    out = clean_text(out)
    return out

# %%
get_tweets(["AAPL"], "2015-12-21")
# Out:
# Fetching keyword AAPL
# '#Siri #AppleMusic – How to Use Siri with Apple Music – Compared to some of the other options li... - #Apple #AAPL #iOS9 #Software – iOS 9.2 Update: 5 Things to Know After 11 Days – The iOS 9.2 update is still ... - #Apple #AAPL Holiday rally time. Back to 2060 ish over next week is my guess for $spy futures. $dia $aapl Is Apple Inc. Losing the Tablet Space to Arun Jaitley? (AAPL, MSFT) #fakeheadlinebot #learntocode #makeatwitterbot #javascript Nielsen: Facebook, Google have the 8 most popular U.S. mobile apps $FB $GOOG $GOOGL $AAPL WTW Weight Watchers Intl Inc. Market Cap $WTW $AAPL $PEGI $COH #WTW #pennystocks #stock $AAPL #TimCook "We pay every tax dollar we owe" vs. The EU commission version What to buy this week?! Watch $AAPL; it\'s a \'buy\' at $92. $DIS Will it dip to $90?! That\'s worth waiting "Total political crap" - Tim Cook on claims Apple evades taxes $AAPL SSO ProShares Ultra S&amp;P 500 Fund Ask $SSO $AMZN $AAPL $NKE #SSO #stock #stock Don\'t forget if you own AAPL Tim Cook is on 60 minutes after football on CBS , we are long Join for free into 2016 Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG) Apple Pay Scales The Great Wall $AAPL c\'mon Aussie! Nielsen: Facebook, Google have the 8 most popular U.S. mobile apps $FB $GOOG $GOOGL $AAPL IBB Biotech iShares Company Info $IBB $AAPL $CTIX $XLY #IBB #stocks #share $XLI Company Info Updated Sunday, December 20, 2015 5:59:23 PM $WLL $AMD $ERX $AAPL $COST Last Price Updated Sunday, December 20, 2015 5:59:23 PM $COP $FDX $AAPL $OWOO FXE Currency Shares Euro Trust Day Low $FXE $CTIX $BHP $AAPL #FXE #stock #finance S&amp;P 500 Crosses Back Below the 200 MA, Now What? #DeathCross $SPY $SPX $TLT $AAPL #investing D/UN.TO Dream Office Real Estate Investment Trust Bid $D/UN.TO $MRK $AEM $AAPL #D/UN.TO #investing #finance Nielsen: Facebook, Google have the 8 most popular U.S. mobile apps $FB $GOOG $GOOGL $AAPL "Total political crap" - Tim Cook on claims Apple evades taxes $AAPL @tim_cook Tim can you tell investors long term growth prospects of #AAPL &amp; with new products in Finance, AUTO &amp; Health.10% Avg.GR.Next 5yrs? @JohnLBair1 @TradeBlueOyster Not trolling. Have other shorts on in this market ($AAPL) that are working good now. $WMIH Recent News Updated Sunday, December 20, 2015 6:06:42 PM $DSLV $JJG $TAN $AAPL @Nccl1331 @JohnLBair1 I am not short $BBRY. Main short now is $AAPL. And working great. :) @JohnArnold18 @Nccl1331 I pulled my short on $BBRY when the chart turned bullish. Biggest short now is $AAPL. Finally gave in and got $nflx . It will be a perfect compliment to the $aapl tv I don\'t use "Total political crap" - Tim Cook on claims Apple evades taxes $AAPL #Siri #AppleMusic – How to Use Siri with Apple Music – Compared to some of the other options li... - #Apple #AAPL #iOS9 #Software – iOS 9.2 Update: 5 Things to Know After 11 Days – The iOS 9.2 update is still ... - #Apple #AAPL $AAPL one of the cheapest, if not the cheapest on both growth and value metrics #investing #trading #TomsTruths I say market opens green tomorrow $QQQ $SPY $NFLX $DIS $FB $AAPL "Total political crap" - Tim Cook on claims Apple evades taxes $AAPL #AAPL #TimCook @60Minutes Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG) Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG) Antonio Villas-Boas/Tech Insider... ＠snapharmony : Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG) Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG), www.HydraM… Flaws in Google\'s latest smartphone made me switch back to iPhone (AAPL, GOOG) "Total political crap" - @tim_cook on claims $AAPL evades taxes - AAPL | Seeking Alpha XIV VelocityShares Daily Inverse VIX Short Term ETN Financials $XIV $NXGA $AAPL $KMI #XIV #share #finance Greatstockpix Video of Stocks to Watch on December 21st $DIS $P $AAPL $VLTC $LL $CLR $GPRO $DDD $KTOV New Post: Distribution Picks Up $SPX  ...

# %%
import json
with open("firm_data.json") as json_file: 
    firm_data = json.loads(json_file.read())
# Out:
# 'Apple'

# %%
firm_data[0]
# Out:
# {'firm': 'Apple',
#  'related_terms': ['iPhone', 'iPad', 'Macbook', 'iOS', 'macOS'],
#  'stock_code': 'AAPL',
#  'ordered': 0}

# %%
data = {}
for firm in firm_data[:3]:
    money = get_stock_dataframe(firm["stock_code"])
    money = money.head(N_DAYS)
    money['tweets']=money.apply(lambda row: get_tweets(firm_data[0]["related_terms"], row["timestamp"]), axis=1)
    data[firm["firm"]]=money[["tweets", "change"]]
# Out:
# Fetching keyword iPhone
# Fetching keyword iPad
# Fetching keyword Macbook
# Fetching keyword iOS
# Fetching keyword macOS
# Fetching keyword iPhone
# Fetching keyword iPad
# Fetching keyword Macbook
# Fetching keyword iOS
# Fetching keyword macOS
# Fetching keyword iPhone
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-91cdcf03d553> in <module>
#       3     money = get_stock_dataframe(firm["stock_code"])
#       4     money = money.head(N_DAYS)
# ----> 5     money['tweets']=money.apply(lambda row: get_tweets(firm_data[0]["related_terms"], row["timestamp"]), axis=1)
#       6     data[firm["firm"]]=money[["tweets", "change"]]
#
# /opt/anaconda3/envs/stox/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/envs/stox/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/envs/stox/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/envs/stox/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-99-91cdcf03d553> in <lambda>(row)
#       3     money = get_stock_dataframe(firm["stock_code"])
#       4     money = money.head(N_DAYS)
# ----> 5     money['tweets']=money.apply(lambda row: get_tweets(firm_data[0]["related_terms"], row["timestamp"]), axis=1)
#       6     data[firm["firm"]]=money[["tweets", "change"]]
#
# <ipython-input-91-225160126506> in get_tweets(keywords, date)
#      13         command = "twint -s '{}' -o {}-{}.csv --csv --since '{}' --until '{}' --limit 1 --lang en".format(keyword, keyword, date, date_before_string, date)
#      14         process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
# ---> 15         process.wait()
#      16         tweet_data = pd.read_csv("{}-{}.csv".format(keyword, date), delimiter="\t")
#      17         result.append(tweet_data["tweet"])
#
# /opt/anaconda3/envs/stox/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# /opt/anaconda3/envs/stox/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
